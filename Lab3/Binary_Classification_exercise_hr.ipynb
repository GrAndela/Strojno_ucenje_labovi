# %% [markdown]
# # Uvod #
#
# U ovoj vježbi izgradit ćete model za predviđanje otkazivanja hotela s binarnim klasifikatorom.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# %% [markdown]
# Prvo učitajte skup podataka *Hotel cancellations*.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('./input/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Definirajte model #
#
# Model koji ćemo ovaj put koristiti imat će i batch normalization i dropout layer. Radi lakšeg čitanja razbili smo dijagram u blokove, ali možete ga definirati sloj po sloj kao i obično.
#
# Definirajte model s arhitekturom danom ovim dijagramom:
#
# <figure style="padding: 1em;">
# <img src="figs/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Dijagram binarnog klasifikatora.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(units=256, activation='relu'),
    layers.Dropout(0.3),
    layers.BatchNormalization(),
    layers.Dense(units=256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(units=1, activation='sigmoid')
])
# Out:
# c:\strojno_ucenje\labs\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:143: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %% [markdown]
# # 2) Dodajte optimizator, loss i metriku #
#
# Sada sastavite model s Adamovim optimizatorom i binarnim verzijama cross-entropy loss-a i metrike accuracy-a.

# %%
# YOUR CODE HERE
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)

# %% [markdown]
# Na kraju, pokrenite ovu ćeliju da uvježbate model i pogledate krivulje učenja. Može trajati oko 60 do 70 epoha, što može potrajati minutu ili dvije.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - binary_accuracy: 0.7427 - loss: 0.5190 - val_binary_accuracy: 0.8064 - val_loss: 0.4379
# Epoch 2/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.7967 - loss: 0.4259 - val_binary_accuracy: 0.8098 - val_loss: 0.4068
# Epoch 3/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8073 - loss: 0.4117 - val_binary_accuracy: 0.8165 - val_loss: 0.3984
# Epoch 4/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8129 - loss: 0.4001 - val_binary_accuracy: 0.8180 - val_loss: 0.3915
# Epoch 5/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8165 - loss: 0.3944 - val_binary_accuracy: 0.8240 - val_loss: 0.3871
# Epoch 6/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.8182 - loss: 0.3926 - val_binary_accuracy: 0.8260 - val_loss: 0.3839
# Epoch 7/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8222 - loss: 0.3866 - val_binary_accuracy: 0.8270 - val_loss: 0.3783
# Epoch 8/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8234 - loss: 0.3802 - val_binary_accuracy: 0.8263 - val_loss: 0.3792
# Epoch 9/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8243 - loss: 0.3777 - val_binary_accuracy: 0.8286 - val_loss: 0.3761
# Epoch 10/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8251 - loss: 0.3764 - val_binary_accuracy: 0.8292 - val_loss: 0.3760
# Epoch 11/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8327 - loss: 0.3684 - val_binary_accuracy: 0.8289 - val_loss: 0.3747
# Epoch 12/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8297 - loss: 0.3696 - val_binary_accuracy: 0.8320 - val_loss: 0.3688
# Epoch 13/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.8297 - loss: 0.3694 - val_binary_accuracy: 0.8309 - val_loss: 0.3687
# Epoch 14/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - binary_accuracy: 0.8324 - loss: 0.3664 - val_binary_accuracy: 0.8323 - val_loss: 0.3680
# Epoch 15/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - binary_accuracy: 0.8347 - loss: 0.3603 - val_binary_accuracy: 0.8321 - val_loss: 0.3684
# Epoch 16/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - binary_accuracy: 0.8327 - loss: 0.3608 - val_binary_accuracy: 0.8346 - val_loss: 0.3649
# Epoch 17/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - binary_accuracy: 0.8355 - loss: 0.3592 - val_binary_accuracy: 0.8337 - val_loss: 0.3629
# Epoch 18/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - binary_accuracy: 0.8363 - loss: 0.3553 - val_binary_accuracy: 0.8333 - val_loss: 0.3666
# Epoch 19/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8362 - loss: 0.3556 - val_binary_accuracy: 0.8350 - val_loss: 0.3625
# Epoch 20/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - binary_accuracy: 0.8351 - loss: 0.3545 - val_binary_accuracy: 0.8341 - val_loss: 0.3636
# Epoch 21/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8346 - loss: 0.3542 - val_binary_accuracy: 0.8371 - val_loss: 0.3598
# Epoch 22/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8392 - loss: 0.3508 - val_binary_accuracy: 0.8349 - val_loss: 0.3646
# Epoch 23/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - binary_accuracy: 0.8400 - loss: 0.3469 - val_binary_accuracy: 0.8362 - val_loss: 0.3601
# Epoch 24/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - binary_accuracy: 0.8386 - loss: 0.3485 - val_binary_accuracy: 0.8379 - val_loss: 0.3591
# Epoch 25/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - binary_accuracy: 0.8393 - loss: 0.3472 - val_binary_accuracy: 0.8359 - val_loss: 0.3631
# Epoch 26/200
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - binary_accuracy: 0.8417 - loss: 0.3451 - val_binary_accuracy: 0.8368 - val_loss: 0.3598
# <Axes: title={'center': 'Accuracy'}>

# %% [markdown]
# # 3) Train and verify #
#
#
# Što mislite o krivuljama učenja? Izgleda li kao model underfit ili overfit? Je li cross-entropy loss bio dobra zamjena za accuracy?
