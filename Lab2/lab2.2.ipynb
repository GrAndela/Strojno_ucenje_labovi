# %% [markdown]
# ## Exercise: Descriptive Statistics
#
# In this notebook, we will investigate and examine data from the stock market, focusing on technology stock, such as Apple for example. In this exercise, we'll use the `pandas`, `numpy`, and `matplotlib` libraries, and will cover concepts like expectance, rolling mean, and visualization of the data. We will learn how to utilize `yfinance` to obtain stock information and visualize various aspects of the data with Seaborn and Matplotlib.
#
# We'll be answering the following questions along the way:
#
# 1.) What was the change in price of the stock over time?\
# 2.) What was the daily return of the stock on average?\
# 3.) What was the moving average of the various stocks?
#
# ### Data Preparation
#
# The initial step involves acquiring the data and loading it into memory. We will obtain our stock information from the Yahoo Finance website, which is a valuable source of financial market data and provides tools for discovering attractive investments. To extract data from Yahoo Finance, we will employ the `yfinance` library, which presents a threaded and Python-friendly approach for downloading market data.

# %%
# %pip install pandas yfinance matplotlib seaborn pandas-datareader setuptools
# Out:
# Requirement already satisfied: pandas in c:\strojno_ucenje\labs\lib\site-packages (2.2.1)
# Requirement already satisfied: yfinance in c:\strojno_ucenje\labs\lib\site-packages (0.2.37)
# Requirement already satisfied: matplotlib in c:\strojno_ucenje\labs\lib\site-packages (3.8.3)
# Requirement already satisfied: seaborn in c:\strojno_ucenje\labs\lib\site-packages (0.13.2)
# Requirement already satisfied: pandas-datareader in c:\strojno_ucenje\labs\lib\site-packages (0.10.0)
# Requirement already satisfied: setuptools in c:\strojno_ucenje\labs\lib\site-packages (69.2.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\strojno_ucenje\labs\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\strojno_ucenje\labs\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\strojno_ucenje\labs\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\strojno_ucenje\labs\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: requests>=2.31 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (2.31.0)
# Requirement already satisfied: multitasking>=0.0.7 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (5.1.0)
# Requirement already satisfied: appdirs>=1.4.4 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: frozendict>=2.3.4 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (2.4.0)
# Requirement already satisfied: peewee>=3.16.2 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (3.17.1)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\strojno_ucenje\labs\lib\site-packages (from yfinance) (1.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\strojno_ucenje\labs\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\strojno_ucenje\labs\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\strojno_ucenje\labs\lib\site-packages (from matplotlib) (4.50.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\strojno_ucenje\labs\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\strojno_ucenje\labs\lib\site-packages (from matplotlib) (24.0)
# Requirement already satisfied: pillow>=8 in c:\strojno_ucenje\labs\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\strojno_ucenje\labs\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: soupsieve>1.2 in c:\strojno_ucenje\labs\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\strojno_ucenje\labs\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\strojno_ucenje\labs\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.31->yfinance) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.31->yfinance) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.31->yfinance) (2024.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install pandas_datareader
# Out:
# Requirement already satisfied: pandas_datareader in c:\strojno_ucenje\labs\lib\site-packages (0.10.0)
# Requirement already satisfied: lxml in c:\strojno_ucenje\labs\lib\site-packages (from pandas_datareader) (5.1.0)
# Requirement already satisfied: pandas>=0.23 in c:\strojno_ucenje\labs\lib\site-packages (from pandas_datareader) (2.2.1)
# Requirement already satisfied: requests>=2.19.0 in c:\strojno_ucenje\labs\lib\site-packages (from pandas_datareader) (2.31.0)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\strojno_ucenje\labs\lib\site-packages (from pandas>=0.23->pandas_datareader) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\strojno_ucenje\labs\lib\site-packages (from pandas>=0.23->pandas_datareader) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\strojno_ucenje\labs\lib\site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\strojno_ucenje\labs\lib\site-packages (from pandas>=0.23->pandas_datareader) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.19.0->pandas_datareader) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\strojno_ucenje\labs\lib\site-packages (from requests>=2.19.0->pandas_datareader) (2024.2.2)
# Requirement already satisfied: six>=1.5 in c:\strojno_ucenje\labs\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.23->pandas_datareader) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# 1. Import necessary libraries: `pandas`, `yfinance`, and `matplotlib`.
# 2. Load the stock data for a specific company (e.g. Apple Inc.) using the `yfinance` library.

# %%
import pandas as pd

# For reading stock data from yahoo
#from pandas_datareader.data import DataReader
import yfinance as yf
#from pandas_datareader import data as pdr

yf.pdr_override()

# For time stamps
from datetime import datetime

# The tech stock we will use for this analysis
company = 'AAPL'

end = datetime.now()
start = datetime(end.year - 1, end.month, end.day)

apple_stock_data = yf.download(company, start, end)

print(apple_stock_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2023-03-28  157.970001  158.490005  ...  156.812973  45992200
# 2023-03-29  159.369995  161.050003  ...  159.916443  51305700
# 2023-03-30  161.529999  162.470001  ...  161.497986  49501700
# 2023-03-31  162.440002  165.000000  ...  164.024490  68749800
# 2023-04-03  164.270004  166.289993  ...  165.287766  56976200
#
# [5 rows x 6 columns]

# %%
apple_stock_data.tail(10)
# Out:
#                   Open        High  ...   Adj Close     Volume
# Date                                ...
# 2024-03-14  172.910004  174.309998  ...  173.000000   72913500
# 2024-03-15  171.169998  172.619995  ...  172.619995  121664700
# 2024-03-18  175.570007  177.710007  ...  173.720001   75604200
# 2024-03-19  174.339996  176.610001  ...  176.080002   55215200
# 2024-03-20  175.720001  178.669998  ...  178.669998   53423100
# 2024-03-21  177.050003  177.490005  ...  171.369995  106181300
# 2024-03-22  171.759995  173.050003  ...  172.279999   71106600
# 2024-03-25  170.570007  171.940002  ...  170.850006   54288300
# 2024-03-26  170.000000  171.419998  ...  169.710007   57388400
# 2024-03-27  170.410004  173.600006  ...  173.309998   60191400
#
# [10 rows x 6 columns]

# %% [markdown]
# Play with code by running it, and experiment with different stock tickers and date ranges.

# %%
import pandas as pd
import yfinance as yf

# Function to fetch stock data for a given company and date range
def fetch_stock_data(company, start_date, end_date):
    # Fetch the stock data using yfinance
    stock_data = yf.download(company, start=start_date, end=end_date)
    return stock_data

# Defining the company tickers I want to fetch data for
companies = ['AAPL', 'GOOG', 'MSFT']

# Defining the date range for the past year
end_date = pd.Timestamp.now()
start_date = end_date - pd.DateOffset(years=1)

# Fetch and display stock data for each company
for company in companies:
    print(f"\nStock Data for {company}:")
    stock_data = fetch_stock_data(company, start_date, end_date)
    print(stock_data.head())
# Out:
# Stock Data for AAPL:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2023-03-28  157.970001  158.490005  ...  156.812973  45992200
# 2023-03-29  159.369995  161.050003  ...  159.916428  51305700
# 2023-03-30  161.529999  162.470001  ...  161.497971  49501700
# 2023-03-31  162.440002  165.000000  ...  164.024490  68749800
# 2023-04-03  164.270004  166.289993  ...  165.287750  56976200
#
# [5 rows x 6 columns]
#
# Stock Data for GOOG:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2023-03-28  103.000000  103.000000  ...  101.360001  24913500
# 2023-03-29  102.720001  102.820000  ...  101.900002  26148300
# 2023-03-30  101.440002  101.610001  ...  101.320000  25009800
# 2023-03-31  101.709999  104.190002  ...  104.000000  28108000
# 2023-04-03  102.669998  104.949997  ...  104.910004  20719900
#
# [5 rows x 6 columns]
#
# Stock Data for MSFT:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2023-03-28  275.790009  276.140015  ...  272.989502  21878600
# 2023-03-29  278.959991  281.140015  ...  278.226562  25087000
# 2023-03-30  284.230011  284.459991  ...  281.737701  25053400
# 2023-03-31  283.730011  289.269989  ...  285.953094  32766000
# 2023-04-03  286.519989  288.269989  ...  284.891815  24883300
#
# [5 rows x 6 columns]

# %% [markdown]
# ### Descriptive Statistics about the Data
#
# The `.describe()` function produces summary statistics, which encompass central tendency, dispersion, and the form of a dataset's distribution, excluding any `NaN` values. It examines numeric and object series, as well as DataFrame columns containing mixed data types. The resulting output depends on the input provided.

# %% [markdown]
# 1. Display the first few rows of the dataset using `head()` function.

# %%
import pandas as pd
import yfinance as yf

# Define the company ticker symbol
company = 'AAPL'

# Fetch the stock data using yfinance
apple_stock_data = yf.download(company, period="1y")

# Display the first few rows of the dataset
print("First few rows of the Apple Inc. stock data:")
print(apple_stock_data.head())
# Out:
# [*********************100%%**********************]  1 of 1 completed
# First few rows of the Apple Inc. stock data:
#                   Open        High  ...   Adj Close    Volume
# Date                                ...
# 2023-03-28  157.970001  158.490005  ...  156.812973  45992200
# 2023-03-29  159.369995  161.050003  ...  159.916428  51305700
# 2023-03-30  161.529999  162.470001  ...  161.497971  49501700
# 2023-03-31  162.440002  165.000000  ...  164.024475  68749800
# 2023-04-03  164.270004  166.289993  ...  165.287735  56976200
#
# [5 rows x 6 columns]

# %% [markdown]
# 2.  Check for missing values and handle them if needed.
#
# First, check for missing values in the dataset using the `isnull()` function and `sum()` to count the number of missing values in each column.

# %%
# Check for missing values in the dataset
missing_values = apple_stock_data.isnull().sum()

# Display the number of missing values in each column
print("Number of missing values in each column:")
print(missing_values)
# Out:
# Number of missing values in each column:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# 3.  Calculate the basic descriptive statistics for the dataset (e.g., mean, median, standard deviation, etc.).
#
# Use the `describe()` function to calculate the basic descriptive statistics for the dataset.

# %%
# Calculate the basic descriptive statistics for the dataset
descriptive_stats = apple_stock_data.describe()

# Display the basic descriptive statistics
print("Basic Descriptive Statistics for the Dataset:")
print(descriptive_stats)
# Out:
# Basic Descriptive Statistics for the Dataset:
#              Open        High         Low       Close   Adj Close        Volume
# count  252.000000  252.000000  252.000000  252.000000  252.000000  2.520000e+02
# mean   180.607620  182.063373  179.273492  180.773532  180.307646  5.739906e+07
# std      9.560096    9.427944    9.480237    9.415627    9.496336  1.720843e+07
# min    157.970001  158.490005  155.979996  157.649994  156.812973  2.404830e+07
# 25%    173.110004  174.307499  171.874996  173.544998  172.997765  4.678918e+07
# 50%    180.379997  182.079994  178.440002  180.640007  180.048981  5.343105e+07
# 75%    189.277496  189.990005  187.652500  189.317501  188.879902  6.203525e+07
# max    198.020004  199.619995  197.000000  198.110001  197.857529  1.366826e+08

# %% [markdown]
# Additionally, you can calculate individual statistics for specific columns, such as the closing price:

# %%
# your code here that calculates the mean, median, and standard deviation of the closing price
mean_close_price = apple_stock_data['Close'].mean()
median_close_price = apple_stock_data['Close'].median()
std_close_price = apple_stock_data['Close'].std()

print("Mean closing price:", mean_close_price)
print("Median closing price:", median_close_price)
print("Standard deviation of closing price:", std_close_price)
# Out:
# Mean closing price: 180.77353201972113
# Median closing price: 180.64000701904297
# Standard deviation of closing price: 9.415627302145497

# %% [markdown]
# ### Information About the Data
#
# `.info()` method prints information about a DataFrame including the index dtype and columns, non-null values, and memory usage.

# %%
print("Information about the Apple Inc. stock data:")
print(apple_stock_data.info())
# Out:
# Information about the Apple Inc. stock data:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 252 entries, 2023-03-28 to 2024-03-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       252 non-null    float64
#  1   High       252 non-null    float64
#  2   Low        252 non-null    float64
#  3   Close      252 non-null    float64
#  4   Adj Close  252 non-null    float64
#  5   Volume     252 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 13.8 KB
# None

# %%
import matplotlib.pyplot as plt

# Let's see a historical view of the closing price
plt.figure(figsize=(12, 6))

# Plotting the closing price
plt.plot(apple_stock_data.index, apple_stock_data['Close'], color='blue', linewidth=1)

# Adding title and labels
plt.title('Historical View of Apple Inc. Closing Price')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Rotating the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### Volume of sales
#
# Trading volume represents the quantity of an asset or security exchanged during a specific time frame, frequently within a day. For example, the daily trading volume of a stock refers to the total number of shares transacted between its opening and closing times. Fluctuations in trading volume over time are significant factors for technical traders to consider.

# %%
import matplotlib.pyplot as plt

# Plotting the total volume of stock being traded each day
plt.figure(figsize=(12, 6))

# Plotting the total volume
plt.plot(apple_stock_data.index, apple_stock_data['Volume'], color='green', linewidth=1)

# Adding title and labels
plt.title('Total Volume of Apple Inc. Stock Traded Each Day')
plt.xlabel('Date')
plt.ylabel('Volume')

# Rotating the x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ## Expectation
#
# In probability theory and statistics, the expectation (or expected value) of a random variable is a measure of the "central tendency" of the distribution of that variable. It is the weighted average of all possible values that the random variable can take on, with the weights being the respective probabilities of those values.
#
# If you have a discrete random variable, the expectation can be computed using the following formula:
#
# E(X) = Σ \[x\_i \* P(x\_i)\]
#
# where x\_i represents the possible values of the random variable X, and P(x\_i) is the probability of each value x\_i.
#
# For a continuous random variable, the expectation is calculated using an integral:
#
# E(X) = ∫ x \* f(x) dx
#
# where x represents the possible values of the random variable X, and f(x) is the probability density function (PDF) of X.
#
# In practice, if you have a dataset of observed values and you want to compute the expectation, you can approximate it by calculating the mean (average) of the values, assuming that each observed value is equally likely.
#
# In the context of stock prices, expectance is the weighted average of all possible values that the stock's closing price can take on. Expectance is important in reinforcement learning because it helps estimate the expected future rewards or values, which in turn aids in the decision-making process. In finance, expectance can give an idea of the long-term average value of a stock, considering all possible outcomes.
#
# 1.  Calculate the expectance of the stock's closing price.
#
# In this case, since we don't have probabilities associated with each closing price, we can assume that all the closing prices are equally likely. Thus, the expectance can be approximated by the mean closing price.

# %%
expectance_close_price = apple_stock_data['Close'].mean()
print("Expectance of the closing price:", expectance_close_price)
# Out:
# Expectance of the closing price: 180.77353201972113

# %% [markdown]
# 3.  Calculate the expectance for a specific time range (e.g., last 30 days).
#
# To calculate the expectance for the last 30 days, first, filter the dataset to include only the last 30 trading days. Then, calculate the mean closing price for this filtered dataset. Use `.iloc[-number_of_days:]` function

# %%
last_30_days = apple_stock_data.iloc[-30:]

expectance_last_30_days = last_30_days['Close'].mean()
print("Expectance of the closing price for the last 30 days:", expectance_last_30_days)
# Out:
# Expectance of the closing price for the last 30 days: 176.31666666666666

# %% [markdown]
# ## Rolling mean - moving average

# %% [markdown]
# The rolling mean, or moving average, is a technique used to smooth out time series data by calculating the average of a fixed-size window of data points as it moves along the time axis. The rolling mean helps reduce noise and random fluctuations in the data, making it easier to identify trends and patterns. It's widely used in finance to analyze stock prices, as well as in reinforcement learning to track the performance of an agent over time.
#
# 1.  Calculate the rolling mean for the stock's closing price with different window sizes (e.g., 7, 14, and 30 days).
#
# To calculate the rolling mean, use the `rolling()` function on the 'Close' column of the stock data with different window sizes and then apply the `mean()` function.

# %%
# Calculate rolling means with window sizes of 7, 14, and 30 days - note that rolling mean for 14 and 30 days is missing
rolling_mean_7 = apple_stock_data['Close'].rolling(window=7).mean()
rolling_mean_14 = apple_stock_data['Close'].rolling(window=14).mean()
rolling_mean_30 = apple_stock_data['Close'].rolling(window=30).mean()

# Add rolling means as new columns to the DataFrame
apple_stock_data['Rolling Mean 7'] = rolling_mean_7
apple_stock_data['Rolling Mean 14'] = rolling_mean_14
apple_stock_data['Rolling Mean 30'] = rolling_mean_30

# Display the first few rows of the dataset with the new columns
print(apple_stock_data.tail())
# Out:
#                   Open        High  ...  Rolling Mean 14  Rolling Mean 30
# Date                                ...
# 2024-03-21  177.050003  177.490005  ...       172.617142       178.423666
# 2024-03-22  171.759995  173.050003  ...       172.415713       177.888999
# 2024-03-25  170.570007  171.940002  ...       172.467856       177.288999
# 2024-03-26  170.000000  171.419998  ...       172.510000       176.707667
# 2024-03-27  170.410004  173.600006  ...       172.817857       176.316667
#
# [5 rows x 9 columns]

# %% [markdown]
# ## Data visualization
#
# The closing market price refers to the last recorded trading price of a stock during the normal trading hours. Investors commonly utilize this price as a standard measure to evaluate the stock's performance throughout a specific time frame. Use 'Adj Close' for plotting this price
#
# 1.  Plot the stock's closing price over time.
#
# To plot the stock's closing price over time, use the `plot()` function from the `matplotlib.pyplot` library on the 'Close' column of the stock data.

# %%
import matplotlib.pyplot as plt

# Plot the stock's closing price over time
plt.figure(figsize=(12, 6))
plt.plot(apple_stock_data.index, apple_stock_data['Close'], color='blue', linewidth=1)

# Add title and labels
plt.title('Apple Inc. Closing Price Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# 2.  Overlay the rolling mean with different window sizes on the closing price plot.
#
# To overlay the rolling mean with different window sizes on the closing price plot, simply add the rolling mean columns to the existing plot.

# %%
import matplotlib.pyplot as plt

# Plot the closing price over time
plt.figure(figsize=(12, 6))
plt.plot(apple_stock_data.index, apple_stock_data['Close'], color='blue', label='Closing Price', linewidth=1)

# Overlay the rolling mean with different window sizes
plt.plot(apple_stock_data.index, apple_stock_data['Rolling Mean 7'], color='red', label='Rolling Mean (7 days)', linewidth=1)
plt.plot(apple_stock_data.index, apple_stock_data['Rolling Mean 14'], color='green', label='Rolling Mean (14 days)', linewidth=1)
plt.plot(apple_stock_data.index, apple_stock_data['Rolling Mean 30'], color='orange', label='Rolling Mean (30 days)', linewidth=1)

# Add title and labels
plt.title('Apple Inc. Closing Price and Rolling Mean Over Time')
plt.xlabel('Date')
plt.ylabel('Price (USD)')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Add legend
plt.legend()

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# ### What was the daily return of the stock on average?
#
# It's time to delve further into the stock's risk assessment. To accomplish this, we must examine the stock's daily fluctuations rather than solely focusing on its absolute value. We will proceed by employing pandas to obtain the daily returns for Apple's stock. Use company `pct_change()` to calculate and plot `'Daily Return'`

# %%
import matplotlib.pyplot as plt

# Calculate the daily returns using pct_change()
apple_stock_data['Daily Return'] = apple_stock_data['Close'].pct_change()

# Plot the daily returns
plt.figure(figsize=(12, 6))
plt.plot(apple_stock_data.index, apple_stock_data['Daily Return'], color='blue', linewidth=1)

# Add title and labels
plt.title('Apple Inc. Daily Returns')
plt.xlabel('Date')
plt.ylabel('Daily Return')

# Rotate x-axis labels for better readability
plt.xticks(rotation=45)

# Display the plot
plt.grid(True)
plt.show()

# %% [markdown]
# Use histogram to take a look at the average daily return - use `hist()` function with 50 bins.

# %%
import matplotlib.pyplot as plt

# Plot a histogram of the average daily return
plt.figure(figsize=(12, 9))
plt.hist(apple_stock_data['Daily Return'], bins=50, color='skyblue', edgecolor='black')

# Add title and labels
plt.title('Histogram of Apple Inc. Average Daily Returns')
plt.xlabel('Average Daily Return')
plt.ylabel('Frequency')

# Display the plot
plt.grid(True)
plt.show()

# %%
import seaborn as sns

# Set the style and size of the plot
sns.set(style='whitegrid')
plt.figure(figsize=(12, 6))

# Plot the histogram and KDE
sns.histplot(apple_stock_data['Daily Return'], kde=True, bins=50)

# Add labels and title
plt.xlabel('Daily Return')
plt.ylabel('Frequency')
plt.title('Apple Stock Daily Return Distribution')

# Show the plot
plt.show()
